# %% [markdown]
# # Group Work

# %%
# %matplotlib inline

# %% [markdown]
# # **Example:** Predict whether Barack Obama or Hillary Clinton will win the Democratic primary in a particular county in 2008:
#
# Hat tip to NYT and Amanda Cox
# Original image available at:

# %%
from IPython.display import Image
Image('clinton.jpg')

# %% [markdown]
# ## Questions
# How does the above compare to our tree visualizations?
#
# What elements are the same?
#
# What makes theirs look more professional?
#
# ## Now for code
# Load the iris dataset
#
# Build a tree
#
# Make and show a graphviz representation
